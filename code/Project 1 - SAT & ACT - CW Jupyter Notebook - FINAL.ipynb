# %% [markdown]
# # Project 1: SAT & ACT Analysis - Christopher Williams

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
#
# # A Texas Size Opportunity for the College Board
#
#
# ### Introduction on Texas focus of SAT & ACT Data
# Texas is the second largest market of SAT test with 226,374 students taking the SAT in 2018 out of the 341,613 High School Graduates or 66% of 2018 class.
#
# In 2018 Texas represents 10.5% of all 2018 US SAT test takers.
#
# As of August 2018, Texas education policy makers at Texas Education Agency have proposed a decision to require the SAT or ACT for high school students as part of their Federally Mandated testing.
#
# “In a proposed change to its administrative rules, the TEA said it would use the ACT and SAT — two standardized tests administered for college admissions — to test those students in high school, and that school districts and charter schools should pay for them.” - Texas Tribune
#
# “Specifically, the proposed amendment would modify subsection (e) to require school districts to use the SAT or ACT to fulfill federal high school assessment requirements for students who took the State of Texas Assessments of Academic Readiness (STAAR®) Algebra I EOC assessment or both the STAAR® English I and English II EOC assessments prior to high school. “
#
# Texas Education Agency (August 24, 2018)
#
# ## Problem Statement
#
#
# In light of the above proposal, how can we use the data provided to help the College Board expand the SAT in the Texas market and not lose the foothold it has to the ACT.
#
#
# ## Executive Summary
#
# This potential change to Texas High School educational testing requirements could be good or bad for the College Board and SAT testing participation in Texas.
#
# The problem is that the College Board could be on the losing side of this proposal if the Texas Legislature and school administrations deem the ACT to be a better exam for their testing needs. The SAT could lose its share of students it currently test.
#
# The data science problem the College Board needs to solve is to empirically prove the SAT is a better test than the ACT for the needs of the Texas Education Agency's federally mandated assessment requirements.
#
# The optimal result would be to gain the rest of the Texas student population.
#
# The information we were provided (discussed above in Overview) is not sufficient to draw conclusions on the problem of empirically proving that the SAT is a better choice than the ACT for measuring student's preparation to fulfill the federally mandated assessments.
#
# As policy makers often make decisions based on average testing score results, we must avoid the pitfalls of policy makers potentially misunderstanding inverse relationship between testing participation and mean scores.
#
# For more of presentation, see pdf titled: Project1 CW SAT, ACT 2017 and 2018 - Focus on Texas - FINAL Presentation

# %% [markdown]
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns
import math

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code to read in SAT and ACT data as pandas dataframes
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code to check fist 10 rows of sat_2017 head
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
# checking first 10 rows of ACT 2017
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
#
#
# The SAT 2017 data is across all 50 US states and DC. It includes 4 parts: Participation, Evidence based Reading and Writing, Math, and finally the Total score.
#
# SAT Participation is a percentage, yet the type is object which will need to be corrected. The parts Evidence based Reading and Writing (ERW), Math and Total are average scores of each category per state. The SAT Participation ranges from 2% to 100% so it's worth looking into why that is so. The ER&W score ranges from 482 to 644 whereas the Math ranges from 52 to 651 with the 52 an outlier needing investigation. For the Total score the range is from 950 to 1295.
#
#
#
#
# The 2017 ACT data consists of 1 row of the national averages of data, and 51 rows of averages of per state (and DC) data. The Participation is a percentage and ranges from 8% to 100% with a National Average of 60%. Whereas the English, Math, Reading, Science, and Composite scores are numerical averages.
#
# ACT 2017 English scores range from 16.3 to 25.5 with a national average of 20.3; Math scores range from 18 to 25.3 with a national average of 20.7; Reading scores range from 18.1 to 26 with a national average of 21.4; and finally Science scores range from 2.3 to 24.9 with a national average of 21, where that 2.3 needs to be investigated and the mean updated accordingly. The Composite score ranges from 17.8 to 25.5 with a National Average of 21.

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
sat_2017
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer:
#
# The SAT 2017 and ACT 2017 data looks complete. As there are no NaN or zeros for any column. However, there are some data issues, which I will discuss below.

# %%
sat_2017.Math.describe()
# Out:
# count     51.000000
# mean     547.627451
# std       84.909119
# min       52.000000
# 25%      522.000000
# 50%      548.000000
# 75%      599.000000
# max      651.000000
# Name: Math, dtype: float64

# %%
sat_2017
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
act_2017
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
#
# Regarding the SAT scores, Maryland's 2017 SAT Math score should be investigated as it is only 52, when the mean for all 50 states and DC is 547. According to the article 'Here are the Average SAT Scores by State' by Kate Sundquist Maryland's 2017 Math score was 524 (source: https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
#
# As far as the 2017 ACT scores, there appears only one egregious error on data collection. Again it's Maryland, but it's Maryland's Science score of 2.3 when the mean is about 21. Only Wyoming's Composite score needs to be modified as it is 20.2x rather than the float (20.2).
#
# Min and Max Scores
#
# The minimum 2017 SAT overall score ranges from 400 to a maximum of 1600. The two required sections of Math and Evidence-Based Reading and Writing both being scored from a minimum of 200-800 (source: https://blog.collegevine.com/how-the-new-sat-is-scored/).
#
# The minimum 2017 ACT composite score ranges from 1 to a maximum of 36. As well, each subject area of the ACT permits scores ranging from a minimum of 1 to a maximum of 36 (source: https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows).

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
# change ACT Maryland's Science score to 23.2 
# source: https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows

act_2017.loc[21,'Science'] = 23.2

# %%
act_2017.loc[21,'Science']
# Out:
# 23.2

# %%
# change ACT Wyoming's Composite score to 20.2 
# source: https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows

act_2017.loc[51,'Composite'] = float(20.2)

# %%
act_2017.loc[51,'Composite']
# Out:
# 20.2

# %%
# correct SAT Maryland's Math score to 524
# https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/
sat_2017.loc[20,'Math'] = 524

# %%
sat_2017.loc[20,'Math']
# Out:
# 524

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
sat.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
#
# The data types for Participation in both the 2017 SAT and ACT dataframes are objects and need to be converted to floats representing them as percentages. The ACT Composite score also needs to be converted to float.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB

# %%
# function to take in df and col as args
def col_percentage_to_float(df, col):
    # using list comprehension to take df[col] and strip %, force change to numeric and divide by 100 to get decimal
    df[col] = df[col].str.strip('%').apply(pd.to_numeric, errors='coerce').div(100)
    print(col_percentage_to_float)

# %%
# applying col_percentage_to_float to SAT 2017's Participation column
col_percentage_to_float(sat_2017, 'Participation')
# Out:
# <function col_percentage_to_float at 0x1a231ecea0>

# %%
# checking SAT 2017's Participation column for correction of dtype
sat_2017.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055

# %%
# applying col_percentage_to_float to ACT 2017's Participation column
col_percentage_to_float(act_2017, 'Participation')
# Out:
# <function col_percentage_to_float at 0x1a231ecea0>

# %%
# checking ACT 2017's Participation column for correction of dtype
act_2017.head()
# Out:
#       State  Participation  English  Math  Reading  Science Composite
# 0  National           0.60     20.3  20.7     21.4     21.0      21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5      19.4

# %%
# checking SAT 2017 dtypes
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
# checking ACT 2017 dtypes
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null float64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(5), object(2)
# memory usage: 2.9+ KB

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# writing function to change to numeric for ACT Composite column
def col_object_to_numeric(df, col):
    df[col] = df[col].apply(pd.to_numeric, errors='coerce')
    print(col_object_to_numeric)

# %%
# applying col_object_to_numeric
col_object_to_numeric(act_2017, 'Composite')
# Out:
# <function col_object_to_numeric at 0x1a23a94d08>

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null float64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#code
sat_2017.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
new_sat_2017_cols = {
    'State': 'state_sat17', 
    'Participation': 'participation_sat17', 
    'Evidence-Based Reading and Writing': 'erw_sat17', 
    'Math': 'math_sat17',
    'Total': 'total_sat17'
}
sat_2017.rename(columns=new_sat_2017_cols, inplace=True)

# %%
sat_2017.head()
# Out:
#   state_sat17  participation_sat17  erw_sat17  math_sat17  total_sat17
# 0     Alabama                 0.05        593         572         1165
# 1      Alaska                 0.38        547         533         1080
# 2     Arizona                 0.30        563         553         1116
# 3    Arkansas                 0.03        614         594         1208
# 4  California                 0.53        531         524         1055

# %%
act_2017.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
new_act_2017_cols = {
    'State': 'state_act17', 
    'Participation': 'participation_act17',
    'English':'english_act17', 
    'Math': 'math_act17',
    'Reading': 'reading_act17',
    'Science': 'science_act17',
    'Composite': 'composite_act17'
}
act_2017.rename(columns=new_act_2017_cols, inplace=True)

# %%
act_2017.head()
# Out:
#   state_act17  participation_act17  english_act17  math_act17  reading_act17  \
# 0    National                 0.60           20.3        20.7           21.4
# 1     Alabama                 1.00           18.9        18.4           19.7
# 2      Alaska                 0.65           18.7        19.8           20.4
# 3     Arizona                 0.62           18.6        19.8           20.1
# 4    Arkansas                 1.00           18.9        19.0           19.7
#
#    science_act17  composite_act17
# 0           21.0             21.0
# 1           19.4             19.2
# 2           19.9             19.8
# 3           19.8             19.7
# 4           19.5             19.4

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Column Name|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|Both|The state data consists of the 50 US states and DC|
# |participation_sat17|float|SAT|The SAT exam participation rate of state's seniors |
# |erw_sat17|int|SAT|ERW is Evidence-Based Reading and Writing average score. Possible range is 200 to 800 |
# |math_sat17|int|SAT| Average Math section score from possible 200 to 800|
# |total_sat17|int|SAT|The Total SAT score averages from possible low of 400 to maximum of 1600|
# |participation_sat18|float|SAT|The SAT exam participation rate of state's seniors |
# |erw_sat18|int|SAT|ERW is Evidence-Based Reading and Writing average score. Possible range is 200 to 800 |
# |math_sat18|int|SAT| Average Math section score from possible 200 to 800|
# |total_sat18|int|SAT|The Total SAT score averages from possible low of 400 to maximum of 1600|
# |participation_act17|float|ACT|The ACT Participation rate per state's seniors|
# |english_act17|float|ACT|The ACT English score ranges from possible low of 1 to maximum of 36|
# |math_act17|float|ACT|The ACT Math score ranges from possible low of 1 to maximum of 36|
# |reading_act17|float|ACT|The ACT Reading score ranges from possible low of 1 to maximum of 36|
# |science_act17|float|ACT|The ACT Science score ranges from possible low of 1 to maximum of 36|
# |composite_act17|float|ACT|The Composite ACT score consists of the averages of the test sections and ranges from possible low of 1 to maximum of 36|
# |participation_act18|float|ACT|The ACT Participation rate per state's seniors|
# |composite_act18|float|ACT|The Composite ACT score consists of the averages of the test sections and ranges from possible low of 1 to maximum of 36|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code
act_2017
# Out:
#              state_act17  participation_act17  english_act17  math_act17  \
# 0               National                 0.60           20.3        20.7
# 1                Alabama                 1.00           18.9        18.4
# 2                 Alaska                 0.65           18.7        19.8
# 3                Arizona                 0.62           18.6        19.8
# 4               Arkansas                 1.00           18.9        19.0
# 5             California                 0.31           22.5        22.7
# 6               Colorado                 1.00           20.1        20.3
# 7            Connecticut                 0.31           25.5        24.6
# 8               Delaware                 0.18           24.1        23.4
# 9   District of Columbia                 0.32           24.4        23.5
# 10               Florida                 0.73           19.0        19.4
# 11               Georgia                 0.55           21.0        20.9
# ...

# %%
# drop act_2017 dataframe row index 0 with state_act17 as National

act_2017 = act_2017.drop([0], axis=0)

# %%
# check act_2017 head to verify correct drop
act_2017.head()
# Out:
#   state_act17  participation_act17  english_act17  math_act17  reading_act17  \
# 1     Alabama                 1.00           18.9        18.4           19.7
# 2      Alaska                 0.65           18.7        19.8           20.4
# 3     Arizona                 0.62           18.6        19.8           20.1
# 4    Arkansas                 1.00           18.9        19.0           19.7
# 5  California                 0.31           22.5        22.7           23.1
#
#    science_act17  composite_act17
# 1           19.4             19.2
# 2           19.9             19.8
# 3           19.8             19.7
# 4           19.5             19.4
# 5           22.2             22.8

# %%
sat_2017.head()
# Out:
#   state_sat17  participation_sat17  erw_sat17  math_sat17  total_sat17
# 0     Alabama                 0.05        593         572         1165
# 1      Alaska                 0.38        547         533         1080
# 2     Arizona                 0.30        563         553         1116
# 3    Arkansas                 0.03        614         594         1208
# 4  California                 0.53        531         524         1055

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
sat_2017.columns
# Out:
# Index(['state_sat17', 'participation_sat17', 'erw_sat17', 'math_sat17',
#        'total_sat17'],
#       dtype='object')

# %%
act_2017.columns
# Out:
# Index(['state_act17', 'participation_act17', 'english_act17', 'math_act17',
#        'reading_act17', 'science_act17', 'composite_act17'],
#       dtype='object')

# %%
# merge sat_2017 and act_2017 on state columns respectively 
sat_act_df_2017 = pd.merge(sat_2017, act_2017, left_on='state_sat17', right_on='state_act17')

# %%
sat_act_df_2017.head()
# Out:
#   state_sat17  participation_sat17  erw_sat17  math_sat17  total_sat17  \
# 0     Alabama                 0.05        593         572         1165
# 1      Alaska                 0.38        547         533         1080
# 2     Arizona                 0.30        563         553         1116
# 3    Arkansas                 0.03        614         594         1208
# 4  California                 0.53        531         524         1055
#
#   state_act17  participation_act17  english_act17  math_act17  reading_act17  \
# 0     Alabama                 1.00           18.9        18.4           19.7
# 1      Alaska                 0.65           18.7        19.8           20.4
# 2     Arizona                 0.62           18.6        19.8           20.1
# 3    Arkansas                 1.00           18.9        19.0           19.7
# 4  California                 0.31           22.5        22.7           23.1
#
#    science_act17  composite_act17
# 0           19.4             19.2
# ...

# %%
sat_act_df_2017.columns
# Out:
# Index(['state_sat17', 'participation_sat17', 'erw_sat17', 'math_sat17',
#        'total_sat17', 'state_act17', 'participation_act17', 'english_act17',
#        'math_act17', 'reading_act17', 'science_act17', 'composite_act17'],
#       dtype='object')

# %%
# rename state_sat17 column to state
sat_act_df_2017.rename(columns={'state_sat17':'state'}, inplace=True)

# %%
# check on rename of column
sat_act_df_2017.head()
# Out:
#         state  participation_sat17  erw_sat17  math_sat17  total_sat17  \
# 0     Alabama                 0.05        593         572         1165
# 1      Alaska                 0.38        547         533         1080
# 2     Arizona                 0.30        563         553         1116
# 3    Arkansas                 0.03        614         594         1208
# 4  California                 0.53        531         524         1055
#
#   state_act17  participation_act17  english_act17  math_act17  reading_act17  \
# 0     Alabama                 1.00           18.9        18.4           19.7
# 1      Alaska                 0.65           18.7        19.8           20.4
# 2     Arizona                 0.62           18.6        19.8           20.1
# 3    Arkansas                 1.00           18.9        19.0           19.7
# 4  California                 0.31           22.5        22.7           23.1
#
#    science_act17  composite_act17
# 0           19.4             19.2
# ...

# %%
# drop the state_act17 column as it's redundant
sat_act_df_2017 = sat_act_df_2017.drop('state_act17', axis=1)

# %%
sat_act_df_2017.head()
# Out:
#         state  participation_sat17  erw_sat17  math_sat17  total_sat17  \
# 0     Alabama                 0.05        593         572         1165
# 1      Alaska                 0.38        547         533         1080
# 2     Arizona                 0.30        563         553         1116
# 3    Arkansas                 0.03        614         594         1208
# 4  California                 0.53        531         524         1055
#
#    participation_act17  english_act17  math_act17  reading_act17  \
# 0                 1.00           18.9        18.4           19.7
# 1                 0.65           18.7        19.8           20.4
# 2                 0.62           18.6        19.8           20.1
# 3                 1.00           18.9        19.0           19.7
# 4                 0.31           22.5        22.7           23.1
#
#    science_act17  composite_act17
# 0           19.4             19.2
# 1           19.9             19.8
# 2           19.8             19.7
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code to save merged dataframe as combined_2017.csv

sat_act_df_2017.to_csv('../data/combined_2017.csv')

# %%
# naming combined_2017 and printing to pandas df
combined_2017 = pd.read_csv('./combined_2017.csv')

# %%
# checking columns
combined_2017.columns
# Out:
# Index(['Unnamed: 0', 'state', 'participation_sat17', 'erw_sat17', 'math_sat17',
#        'total_sat17', 'participation_act17', 'english_act17', 'math_act17',
#        'reading_act17', 'science_act17', 'composite_act17'],
#       dtype='object')

# %%
# dropping 'Unnamed: 0' column
combined_2017 = combined_2017.drop('Unnamed: 0', axis=1)

# %%
# checking combined_2017 
combined_2017.head()
# Out:
#         state  participation_sat17  erw_sat17  math_sat17  total_sat17  \
# 0     Alabama                 0.05        593         572         1165
# 1      Alaska                 0.38        547         533         1080
# 2     Arizona                 0.30        563         553         1116
# 3    Arkansas                 0.03        614         594         1208
# 4  California                 0.53        531         524         1055
#
#    participation_act17  english_act17  math_act17  reading_act17  \
# 0                 1.00           18.9        18.4           19.7
# 1                 0.65           18.7        19.8           20.4
# 2                 0.62           18.6        19.8           20.1
# 3                 1.00           18.9        19.0           19.7
# 4                 0.31           22.5        22.7           23.1
#
#    science_act17  composite_act17
# 0           19.4             19.2
# 1           19.9             19.8
# 2           19.8             19.7
# ...

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
sat_2018 = pd.read_csv('../data/sat_2018.csv')

# %%
act_2018 = pd.read_csv('../data/act_2018.csv')

# %%
sat_2018.head(25)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado           28%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           97%                                 522
# 10               Georgia           70%                                 542
# ...

# %%
# colorado participation rate is 100%, making change here
sat_2018.loc[[5],['Participation']] = '100%'

# %%
sat_2018.loc[[5],['Participation']]
# Out:
#   Participation
# 5          100%

# %%
# checking correction
sat_2018.head(6)
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1168
# 4  California           60%                                 540   536   1076
# 5    Colorado          100%                                 519   506   1025

# %%
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
# State                                 52 non-null object
# Participation                         52 non-null object
# Evidence-Based Reading and Writing    52 non-null int64
# Math                                  52 non-null int64
# Total                                 52 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
# State            52 non-null object
# Participation    52 non-null object
# Composite        52 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
# use col_percentage_to_float function to change sat_2018 Participation column to float
col_percentage_to_float(sat_2018, 'Participation')
# Out:
# <function col_percentage_to_float at 0x1a231ecea0>

# %%
# check conversion
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
# use col_percentage_to_float function to change act_2018 Participation column to float
col_percentage_to_float(act_2018, 'Participation')
# Out:
# <function col_percentage_to_float at 0x1a231ecea0>

# %%
# check conversion
act_2018.head()
# Out:
#         State  Participation  Composite
# 0     Alabama           1.00       19.1
# 1      Alaska           0.33       20.8
# 2     Arizona           0.66       19.2
# 3    Arkansas           1.00       19.4
# 4  California           0.27       22.7

# %%
# check sat_2018 dtypes
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
# State                                 52 non-null object
# Participation                         52 non-null float64
# Evidence-Based Reading and Writing    52 non-null int64
# Math                                  52 non-null int64
# Total                                 52 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
# check act_2018 dtypes
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
# State            52 non-null object
# Participation    52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
sat_2018.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
# change sat_2018 column heads to lowercase and consistent with 2017's
new_sat_2018_cols = {
    'State': 'state_sat18', 
    'Participation': 'participation_sat18', 
    'Evidence-Based Reading and Writing': 'erw_sat18', 
    'Math': 'math_sat18',
    'Total': 'total_sat18'
}
sat_2018.rename(columns=new_sat_2018_cols, inplace=True)

# %%
# check new sat_2018 columns
sat_2018.columns
# Out:
# Index(['state_sat18', 'participation_sat18', 'erw_sat18', 'math_sat18',
#        'total_sat18'],
#       dtype='object')

# %%
act_2018.columns
# Out:
# Index(['State', 'Participation', 'Composite'], dtype='object')

# %%
# change act_2018 column heads to lowercase and consistent with 2017's
new_act_2018_cols = {
    'State': 'state_act18', 
    'Participation': 'participation_act18',
    'Composite': 'composite_act18'
}
act_2018.rename(columns=new_act_2018_cols, inplace=True)

# %%
# check new act_2018 columns
act_2018.columns
# Out:
# Index(['state_act18', 'participation_act18', 'composite_act18'], dtype='object')

# %%
# need to rename act_2018's Washington, D.C. to District of Columbia
# it is in row index 8 column index state_act18 
act_2018.loc[8,'state_act18'] = 'District of Columbia'

# %%
# checking change to row index 8 column index state_act18 
act_2018.loc[8,'state_act18']
# Out:
# 'District of Columbia'

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# mergering sat_2018 and act_2018 dataframes together on state columns respectively
sat_act_df_2018 = pd.merge(sat_2018, act_2018, left_on='state_sat18', right_on='state_act18')

# %%
# examining whole dataframe, notice that there is a national row in 2018, but not in 2017
# will delete national in 2018 to merge with 2017 dataframe as national data will get in way of modeling 
sat_act_df_2018
# Out:
#              state_sat18  participation_sat18  erw_sat18  math_sat18  \
# 0                Alabama                 0.06        595         571
# 1                 Alaska                 0.43        562         544
# 2                Arizona                 0.29        577         572
# 3               Arkansas                 0.05        592         576
# 4             California                 0.60        540         536
# 5               Colorado                 1.00        519         506
# 6            Connecticut                 1.00        535         519
# 7               Delaware                 1.00        505         492
# 8   District of Columbia                 0.92        497         480
# 9                Florida                 0.97        522         493
# 10               Georgia                 0.70        542         522
# 11                Hawaii                 0.56        550         549
# 12                 Idaho                 1.00        508         493
# ...

# %%
# saving sat_act_df_2018_national row in case of need later
sat_act_df_2018_national = sat_act_df_2018.iloc[[51],:]

# %%
# drop sat_act_df_2018_national row
sat_act_df_2018 = sat_act_df_2018.drop(sat_act_df_2018.index[-1])

# %%
# checking tail to see if properly dropped
sat_act_df_2018.tail()
# Out:
#       state_sat18  participation_sat18  erw_sat18  math_sat18  total_sat18  \
# 46       Virginia                 0.68        567         550         1117
# 47     Washington                 0.69        543         538         1081
# 48  West Virginia                 0.28        513         486          999
# 49      Wisconsin                 0.03        641         653         1294
# 50        Wyoming                 0.03        633         625         1258
#
#       state_act18  participation_act18  composite_act18
# 46       Virginia                 0.24             23.9
# 47     Washington                 0.24             22.2
# 48  West Virginia                 0.65             20.3
# 49      Wisconsin                 1.00             20.5
# 50        Wyoming                 1.00             20.0

# %%
# dropping redudant column state_act18
sat_act_df_2018 = sat_act_df_2018.drop('state_act18', axis=1)

# %%
sat_act_df_2018.head()
# Out:
#   state_sat18  participation_sat18  erw_sat18  math_sat18  total_sat18  \
# 0     Alabama                 0.06        595         571         1166
# 1      Alaska                 0.43        562         544         1106
# 2     Arizona                 0.29        577         572         1149
# 3    Arkansas                 0.05        592         576         1168
# 4  California                 0.60        540         536         1076
#
#    participation_act18  composite_act18
# 0                 1.00             19.1
# 1                 0.33             20.8
# 2                 0.66             19.2
# 3                 1.00             19.4
# 4                 0.27             22.7

# %%
sat_act_df_2017.head()
# Out:
#         state  participation_sat17  erw_sat17  math_sat17  total_sat17  \
# 0     Alabama                 0.05        593         572         1165
# 1      Alaska                 0.38        547         533         1080
# 2     Arizona                 0.30        563         553         1116
# 3    Arkansas                 0.03        614         594         1208
# 4  California                 0.53        531         524         1055
#
#    participation_act17  english_act17  math_act17  reading_act17  \
# 0                 1.00           18.9        18.4           19.7
# 1                 0.65           18.7        19.8           20.4
# 2                 0.62           18.6        19.8           20.1
# 3                 1.00           18.9        19.0           19.7
# 4                 0.31           22.5        22.7           23.1
#
#    science_act17  composite_act17
# 0           19.4             19.2
# 1           19.9             19.8
# 2           19.8             19.7
# ...

# %%
# merge 2017 and 2018 dataframes on state columns respectively 
final = pd.merge(sat_act_df_2017, sat_act_df_2018, left_on='state', right_on='state_sat18')

# %%
# checking head
# need to drop stat_sat18 as states are redundant
final.head()
# Out:
#         state  participation_sat17  erw_sat17  math_sat17  total_sat17  \
# 0     Alabama                 0.05        593         572         1165
# 1      Alaska                 0.38        547         533         1080
# 2     Arizona                 0.30        563         553         1116
# 3    Arkansas                 0.03        614         594         1208
# 4  California                 0.53        531         524         1055
#
#    participation_act17  english_act17  math_act17  reading_act17  \
# 0                 1.00           18.9        18.4           19.7
# 1                 0.65           18.7        19.8           20.4
# 2                 0.62           18.6        19.8           20.1
# 3                 1.00           18.9        19.0           19.7
# 4                 0.31           22.5        22.7           23.1
#
#    science_act17  composite_act17 state_sat18  participation_sat18  erw_sat18  \
# ...

# %%
# dropping 'state_sat18' column in final dataframe
final = final.drop('state_sat18', axis=1)

# %%
# checking to see changes are complete
final.head()
# Out:
#         state  participation_sat17  erw_sat17  math_sat17  total_sat17  \
# 0     Alabama                 0.05        593         572         1165
# 1      Alaska                 0.38        547         533         1080
# 2     Arizona                 0.30        563         553         1116
# 3    Arkansas                 0.03        614         594         1208
# 4  California                 0.53        531         524         1055
#
#    participation_act17  english_act17  math_act17  reading_act17  \
# 0                 1.00           18.9        18.4           19.7
# 1                 0.65           18.7        19.8           20.4
# 2                 0.62           18.6        19.8           20.1
# 3                 1.00           18.9        19.0           19.7
# 4                 0.31           22.5        22.7           23.1
#
#    science_act17  composite_act17  participation_sat18  erw_sat18  math_sat18  \
# ...

# %%
# checking dtpyes of final
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 17 columns):
# state                  51 non-null object
# participation_sat17    51 non-null float64
# erw_sat17              51 non-null int64
# math_sat17             51 non-null int64
# total_sat17            51 non-null int64
# participation_act17    51 non-null float64
# english_act17          51 non-null float64
# math_act17             51 non-null float64
# reading_act17          51 non-null float64
# science_act17          51 non-null float64
# composite_act17        51 non-null float64
# participation_sat18    51 non-null float64
# erw_sat18              51 non-null int64
# math_sat18             51 non-null int64
# total_sat18            51 non-null int64
# participation_act18    51 non-null float64
# composite_act18        51 non-null float64
# dtypes: float64(10), int64(6), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final.describe().T
# Out:
#                      count         mean        std     min       25%      50%  \
# participation_sat17   51.0     0.398039   0.352766    0.02     0.040     0.38
# erw_sat17             51.0   569.117647  45.666901  482.00   533.500   559.00
# math_sat17            51.0   556.882353  47.121395  468.00   523.500   548.00
# total_sat17           51.0  1126.098039  92.494812  950.00  1055.500  1107.00
# participation_act17   51.0     0.652549   0.321408    0.08     0.310     0.69
# english_act17         51.0    20.931373   2.353677   16.30    19.000    20.70
# math_act17            51.0    21.182353   1.981989   18.00    19.400    20.90
# reading_act17         51.0    22.013725   2.067271   18.10    20.450    21.80
# science_act17         51.0    21.450980   1.739353   18.20    19.950    21.30
# composite_act17       51.0    21.519608   2.020695   17.80    19.800    21.40
# participation_sat18   51.0     0.466471   0.379915    0.02     0.045     0.52
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def stand_deviation(cols):
    mean = sum(cols) / len(cols)
    num = len(cols)
    diff = [x- mean for x in cols]
    sq_diff = [d**2 for d in diff]
    ssd = sum(sq_diff)
    variance = ssd / num
    stdev = (variance ** .5)
    return stdev

# %%
# run stand_deviation function to compare with other functions such as numpy's built in std checker
stand_deviation(final['erw_sat17'])
# Out:
# 45.21697020437866

# %%
# Numpy std method of ERW of SAT 2017
np.std(final['erw_sat17'])
# Out:
# 45.21697020437866

# %%
# Numpy std method of Math of SAT 2018
np.std(final['math_sat18'])
# Out:
# 48.97751133618255

# %%
# Numpy std method of Reading of ACT 2017
np.std(final['reading_act17'])
# Out:
# 2.0469029314842646

# %%
# Numpy std method of Math of ACT 2017
np.std(final['math_act17'])
# Out:
# 1.9624620273436781

# %%
# Numpy std method of Total of SAT 2018
np.std(final['total_sat18'])
# Out:
# 93.51362961350053

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
final.columns[1]
# Out:
# 'participation_sat17'

# %%
for col in final.columns[1:]:
    print(final[col].mean())
# Out:
# 0.39803921568627454
# 569.1176470588235
# 556.8823529411765
# 1126.0980392156862
# 0.6525490196078431
# 20.931372549019606
# 21.182352941176468
# 22.013725490196077
# 21.45098039215686
# 21.519607843137255
# 0.466470588235294
# 567.7058823529412
# 558.4509803921569
# 1126.1568627450981
# 0.6172549019607843
# 21.49607843137255

# %%
#for col in final.columns[1:]:
#   print(stand_deviation(cols))

# %%
#{final[i]:stand_deviation for key, value in final[i]}

# %%
a = [1,2,3]
b = [4,5,6]

# %%
[a+ b for a,b in zip(a,b)]
# Out:
# [5, 7, 9]

# %%
c = zip(a,b)

# %%
{a:b for a,b in zip(a,b)}
# Out:
# {1: 4, 2: 5, 3: 6}

# %%
#{k,v for final[col]: stand_dev_final(col) in final}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer
# Yes, my manually calculated standard deviations match up with the output from pandas describe and with the numpy's std method.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# I am interested in Texas, Colorado and Illinois. Colorado and Illinois changed their policies and I want to see what potentially we could takeawy to help College Board on its proposal with Texas.
#
# Please see the following tables to see rankings of States based on different measurements and indicators.

# %%
# 2017 SAT Ranking of lowest participation rates
final.head()
# Out:
#         state  participation_sat17  erw_sat17  math_sat17  total_sat17  \
# 0     Alabama                 0.05        593         572         1165
# 1      Alaska                 0.38        547         533         1080
# 2     Arizona                 0.30        563         553         1116
# 3    Arkansas                 0.03        614         594         1208
# 4  California                 0.53        531         524         1055
#
#    participation_act17  english_act17  math_act17  reading_act17  \
# 0                 1.00           18.9        18.4           19.7
# 1                 0.65           18.7        19.8           20.4
# 2                 0.62           18.6        19.8           20.1
# 3                 1.00           18.9        19.0           19.7
# 4                 0.31           22.5        22.7           23.1
#
#    science_act17  composite_act17  participation_sat18  erw_sat18  math_sat18  \
# ...

# %%
# 2017 SAT States with highest participation rate
final.sort_values('participation_sat17', ascending=False).loc[:,['state','participation_sat17']].head(10)
# Out:
#                    state  participation_sat17
# 8   District of Columbia                 1.00
# 22              Michigan                 1.00
# 6            Connecticut                 1.00
# 7               Delaware                 1.00
# 29         New Hampshire                 0.96
# 19                 Maine                 0.95
# 12                 Idaho                 0.93
# 9                Florida                 0.83
# 21         Massachusetts                 0.76
# 39          Rhode Island                 0.71

# %%
# 2017 SAT 5 States with lowest participation rate
final.sort_values('participation_sat17').loc[:,['state','participation_sat17']].head()
# Out:
#            state  participation_sat17
# 34  North Dakota                 0.02
# 24   Mississippi                 0.02
# 15          Iowa                 0.02
# 25      Missouri                 0.03
# 44          Utah                 0.03

# %%
# 2018 SAT 5 States with highest participation rate
final.sort_values('participation_sat17', ascending=False).loc[:,['state','participation_sat18']].head(10)
# Out:
#                    state  participation_sat18
# 8   District of Columbia                 0.92
# 22              Michigan                 1.00
# 6            Connecticut                 1.00
# 7               Delaware                 1.00
# 29         New Hampshire                 0.96
# 19                 Maine                 0.99
# 12                 Idaho                 1.00
# 9                Florida                 0.97
# 21         Massachusetts                 0.80
# 39          Rhode Island                 0.97

# %%
# 2018 SAT 5 States with lowest participation rate
final.sort_values('participation_sat18').loc[:,['state','participation_sat18']].head()
# Out:
#            state  participation_sat18
# 34  North Dakota                 0.02
# 50       Wyoming                 0.03
# 41  South Dakota                 0.03
# 27      Nebraska                 0.03
# 49     Wisconsin                 0.03

# %%
# 2017 ACT 5 States with highest participation rate
final.sort_values('participation_act17', ascending=False).loc[:,['state','participation_act17']].head(25)
# Out:
#              state  participation_act17
# 0          Alabama                 1.00
# 17        Kentucky                 1.00
# 49       Wisconsin                 1.00
# 44            Utah                 1.00
# 42       Tennessee                 1.00
# 40  South Carolina                 1.00
# 36        Oklahoma                 1.00
# 33  North Carolina                 1.00
# 28          Nevada                 1.00
# 26         Montana                 1.00
# 24     Mississippi                 1.00
# 23       Minnesota                 1.00
# 18       Louisiana                 1.00
# 25        Missouri                 1.00
# 50         Wyoming                 1.00
# 5         Colorado                 1.00
# 3         Arkansas                 1.00
# 34    North Dakota                 0.98
# 13        Illinois                 0.93
# 11          Hawaii                 0.90
# 27        Nebraska                 0.84
# 41    South Dakota                 0.80
# ...

# %%
# 2017 ACT 5 States with lowest participation rate
final.sort_values('participation_act17').loc[:,['state','participation_act17']].head()
# Out:
#             state  participation_act17
# 19          Maine                 0.08
# 29  New Hampshire                 0.18
# 7        Delaware                 0.18
# 39   Rhode Island                 0.21
# 38   Pennsylvania                 0.23

# %%
# 2018 ACT States with highest participation rate
# 17 states have 100% ACT participation
final.sort_values('participation_act18', ascending=False).loc[:,['state','participation_act18']].head(20)
# Out:
#              state  participation_act18
# 0          Alabama                 1.00
# 17        Kentucky                 1.00
# 49       Wisconsin                 1.00
# 44            Utah                 1.00
# 42       Tennessee                 1.00
# 40  South Carolina                 1.00
# 36        Oklahoma                 1.00
# 35            Ohio                 1.00
# 33  North Carolina                 1.00
# 28          Nevada                 1.00
# 27        Nebraska                 1.00
# 26         Montana                 1.00
# 24     Mississippi                 1.00
# 18       Louisiana                 1.00
# 25        Missouri                 1.00
# 50         Wyoming                 1.00
# 3         Arkansas                 1.00
# 23       Minnesota                 0.99
# 34    North Dakota                 0.98
# 11          Hawaii                 0.89

# %%
# 2018 ACT 5 States with lowest participation rate
final.sort_values('participation_act18').loc[:,['state','participation_act18']].head()
# Out:
#             state  participation_act18
# 19          Maine                 0.07
# 39   Rhode Island                 0.15
# 29  New Hampshire                 0.16
# 7        Delaware                 0.17
# 38   Pennsylvania                 0.20

# %%
final.head()
# Out:
#         state  participation_sat17  erw_sat17  math_sat17  total_sat17  \
# 0     Alabama                 0.05        593         572         1165
# 1      Alaska                 0.38        547         533         1080
# 2     Arizona                 0.30        563         553         1116
# 3    Arkansas                 0.03        614         594         1208
# 4  California                 0.53        531         524         1055
#
#    participation_act17  english_act17  math_act17  reading_act17  \
# 0                 1.00           18.9        18.4           19.7
# 1                 0.65           18.7        19.8           20.4
# 2                 0.62           18.6        19.8           20.1
# 3                 1.00           18.9        19.0           19.7
# 4                 0.31           22.5        22.7           23.1
#
#    science_act17  composite_act17  participation_sat18  erw_sat18  math_sat18  \
# ...

# %% [markdown]
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?

# %%
# 2017 SAT 5 States with highest total score
final.sort_values('total_sat17', ascending=False).loc[:,['state','total_sat17']].head(5)
# Out:
#         state  total_sat17
# 23  Minnesota         1295
# 49  Wisconsin         1291
# 15       Iowa         1275
# 25   Missouri         1271
# 16     Kansas         1260

# %%
# 2017 SAT 5 States with lowest total score
final.sort_values('total_sat17', ascending=True).loc[:,['state','total_sat17']].head(5)
# Out:
#                    state  total_sat17
# 8   District of Columbia          950
# 7               Delaware          996
# 12                 Idaho         1005
# 22              Michigan         1005
# 19                 Maine         1012

# %%
# 2018 SAT 5 States with highest total score
final.sort_values('total_sat18', ascending=False).loc[:,['state','total_sat18']].head(5)
# Out:
#            state  total_sat18
# 23     Minnesota         1298
# 49     Wisconsin         1294
# 34  North Dakota         1283
# 25      Missouri         1272
# 15          Iowa         1265

# %%
# 2018 SAT 5 States with lowest total score
final.sort_values('total_sat18', ascending=True).loc[:,['state','total_sat18']].head(5)
# Out:
#                    state  total_sat18
# 8   District of Columbia          977
# 7               Delaware          997
# 48         West Virginia          999
# 12                 Idaho         1001
# 22              Michigan         1010

# %%
# 2017 ACT 5 States with highest total score
final.sort_values('composite_act17', ascending=False).loc[:,['state','composite_act17']].head(5)
# Out:
#                    state  composite_act17
# 29         New Hampshire             25.5
# 21         Massachusetts             25.4
# 6            Connecticut             25.2
# 19                 Maine             24.3
# 8   District of Columbia             24.2

# %%
# 2017 ACT 5 States with lowest total score
final.sort_values('composite_act17', ascending=True).loc[:,['state','composite_act17']].head(5)
# Out:
#              state  composite_act17
# 28          Nevada             17.8
# 24     Mississippi             18.6
# 40  South Carolina             18.7
# 11          Hawaii             19.0
# 33  North Carolina             19.1

# %%
# 2018 ACT 5 States with highest total score
final.sort_values('composite_act18', ascending=False).loc[:,['state','composite_act18']].head(5)
# Out:
#             state  composite_act18
# 6     Connecticut             25.6
# 21  Massachusetts             25.5
# 29  New Hampshire             25.1
# 32       New York             24.5
# 22       Michigan             24.2

# %%
# 2018 ACT 5 States with lowest total score
final.sort_values('composite_act18', ascending=True).loc[:,['state','composite_act18']].head(5)
# Out:
#              state  composite_act18
# 28          Nevada             17.7
# 40  South Carolina             18.3
# 24     Mississippi             18.6
# 11          Hawaii             18.9
# 0          Alabama             19.1

# %% [markdown]
# - Do any states with 100% participation on a given test have a rate change year-to-year?

# %%
# Checking to see if 2017 versus 2018 ACT participation changed for states with 100%
# It did changed for Colorado from 100% in 2017 to 30% in 2018
# And Minnesota changed from 100% in 2017 to 99% in 2018
final.loc[(final['participation_act17']==1) & (final['participation_act18']!=1),:]
# Out:
#         state  participation_sat17  erw_sat17  math_sat17  total_sat17  \
# 5    Colorado                 0.11        606         595         1201
# 23  Minnesota                 0.03        644         651         1295
#
#     participation_act17  english_act17  math_act17  reading_act17  \
# 5                   1.0           20.1        20.3           21.2
# 23                  1.0           20.4        21.5           21.8
#
#     science_act17  composite_act17  participation_sat18  erw_sat18  \
# 5            20.9             20.8                 1.00        519
# 23           21.6             21.5                 0.04        643
#
#     math_sat18  total_sat18  participation_act18  composite_act18
# 5          506         1025                 0.30             23.9
# 23         655         1298                 0.99             21.3

# %%
# Checking to see if 2017 versus 2018 SAT participation changed for states with 100%
# It did not change in any states.
final.loc[(final['participation_sat17']==1) & (final['participation_sat18']!=1),:]
# Out:
#                   state  participation_sat17  erw_sat17  math_sat17  \
# 8  District of Columbia                  1.0        482         468
#
#    total_sat17  participation_act17  english_act17  math_act17  reading_act17  \
# 8          950                 0.32           24.4        23.5           24.9
#
#    science_act17  composite_act17  participation_sat18  erw_sat18  math_sat18  \
# 8           23.5             24.2                 0.92        497         480
#
#    total_sat18  participation_act18  composite_act18
# 8          977                 0.32             23.6

# %% [markdown]
# - Do any states show have >50% participation on both tests either year?

# %%
# Checking to see which states had greater than 50% participation in 2017 in both tests.
# FL, GA, HI, IL, NC, and SC did. 
final.loc[(final['participation_act17']>=.5) & (final['participation_sat17']>= .5),:]
# Out:
#              state  participation_sat17  erw_sat17  math_sat17  total_sat17  \
# 9          Florida                 0.83        520         497         1017
# 10         Georgia                 0.61        535         515         1050
# 11          Hawaii                 0.55        544         541         1085
# 40  South Carolina                 0.50        543         521         1064
#
#     participation_act17  english_act17  math_act17  reading_act17  \
# 9                  0.73           19.0        19.4           21.0
# 10                 0.55           21.0        20.9           22.0
# 11                 0.90           17.8        19.2           19.2
# 40                 1.00           17.5        18.6           19.1
#
#     science_act17  composite_act17  participation_sat18  erw_sat18  \
# 9            19.4             19.8                 0.97        522
# 10           21.3             21.4                 0.70        542
# ...

# %%
# Checking to see which states had greater than 50% participation in 2018 in both tests.
# FL, GA, HI, NC, and SC did. IL did not like they had in 2017.
final.loc[(final['participation_act18']>=.5) & (final['participation_sat18'] >=.5), :]
# Out:
#              state  participation_sat17  erw_sat17  math_sat17  total_sat17  \
# 9          Florida                 0.83        520         497         1017
# 10         Georgia                 0.61        535         515         1050
# 11          Hawaii                 0.55        544         541         1085
# 33  North Carolina                 0.49        546         535         1081
# 40  South Carolina                 0.50        543         521         1064
#
#     participation_act17  english_act17  math_act17  reading_act17  \
# 9                  0.73           19.0        19.4           21.0
# 10                 0.55           21.0        20.9           22.0
# 11                 0.90           17.8        19.2           19.2
# 33                 1.00           17.8        19.3           19.6
# 40                 1.00           17.5        18.6           19.1
#
#     science_act17  composite_act17  participation_sat18  erw_sat18  \
# ...

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize=(12,12))
plt.title('HeatMap of 2017 & 2018 SAT & ACT National Data')
sns.heatmap(final.corr(), annot=True);
plt.xticks(rotation=45);

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(10,6)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], bins=8) # feel free to add more settings
        ax[i].set_ylabel(list_of_ylabels[i]) # Set titles, labels, etc here for each subplot
        ax[i].set_xlabel(list_of_xlabels[i])        
        ax[i].set_title(list_of_titles[i])

# %%
final.columns
# Out:
# Index(['state', 'participation_sat17', 'erw_sat17', 'math_sat17',
#        'total_sat17', 'participation_act17', 'english_act17', 'math_act17',
#        'reading_act17', 'science_act17', 'composite_act17',
#        'participation_sat18', 'erw_sat18', 'math_sat18', 'total_sat18',
#        'participation_act18', 'composite_act18'],
#       dtype='object')

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
act_vs_sat_2017 = ['participation_sat17', "participation_act17"]
list_of_ylabels = ['Number of States', 'Number of States']
titles_2017 = ["SAT 2017 State Percentage Participation", "ACT 2017 State Percentage Participation"]
subplot_histograms(final, act_vs_sat_2017, titles_2017, act_vs_sat_2017, list_of_ylabels)

# %%
act_vs_sat_2018 = ['participation_sat18', "participation_act18"]
list_of_ylabels = ['Number of States', 'Number of States']
titles_2018 = ["SAT 2018 State Percentage Participation", "ACT 2018 State Percentage Participation"]
subplot_histograms(final, act_vs_sat_2018, titles_2018, act_vs_sat_2018, list_of_ylabels)

# %%
# Math Scores 2017 SAT ACT

act_vs_sat_2017 = ['math_sat17', "math_act17"]
list_of_ylabels = ['Number of States', 'Number of States']
titles_2017 = ["SAT 2017 State Scoring Average", "ACT 2017 State Scoring Average"]
subplot_histograms(final, act_vs_sat_2017, titles_2017, act_vs_sat_2017, list_of_ylabels)

# %%
# Math Scores 2018 SAT ACT
# there is no 2018 ACT Math

act_vs_sat_2018 = ['math_sat18']
list_of_ylabels = ['Number of States', 'Number of States']
titles_2018 = ["SAT 2018 State Scoring Average", "ACT 2018 State Scoring Average"]
subplot_histograms(final, act_vs_sat_2018, titles_2018, act_vs_sat_2018, list_of_ylabels)

# %%
final.columns
# Out:
# Index(['state', 'participation_sat17', 'erw_sat17', 'math_sat17',
#        'total_sat17', 'participation_act17', 'english_act17', 'math_act17',
#        'reading_act17', 'science_act17', 'composite_act17',
#        'participation_sat18', 'erw_sat18', 'math_sat18', 'total_sat18',
#        'participation_act18', 'composite_act18'],
#       dtype='object')

# %%
#  2017 SAT ACT Reading Scores
# Reading/verbal scores for SAT & ACT

act_vs_sat_2017 = ['erw_sat17', "reading_act17"]
list_of_ylabels = ['Number of States', 'Number of States']
titles_2017 = ["No. of States that are in Scoring Range \n SAT Evidence-Based Reading & Writing 2017", "No. of States that are in Scoring Range \nACT Reading 2017"]
subplot_histograms(final, act_vs_sat_2017, titles_2017, act_vs_sat_2017, list_of_ylabels)

# %%
#  2018 SAT ACT Reading Scores
# Reading ACT were not included

act_vs_sat_2018 = ['erw_sat18']
list_of_ylabels = ['Number of States']
titles_2018 = ["No. of States that are in Scoring Range \n SAT Evidence-Based Reading & Writing 2018", "No. of States that are in Scoring Range \nACT Reading 2017"]
subplot_histograms(final, act_vs_sat_2018, titles_2018, act_vs_sat_2018, list_of_ylabels)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %% [markdown]
# #### SAT vs. ACT math scores for 2017
#
# The below SAT vs. ACT math scores for 2017 demonstrate that there tends to be clusters of states that score either really well on ACT or SAT math. This may be due to that the states have higher or lower particpation in each test tend to score on average better inversly to their participation as students may self select themselves to take the non-required test.

# %%
# SAT vs. ACT math scores for 2017
plt.figure(figsize=(5,5))
plt.title('SAT vs. ACT math scores for 2017')
sns.scatterplot(final['math_act17'], final['math_sat17'])
plt.xlabel('SAT Math Scores Averages per State')
plt.ylabel('ACT Math Score Averages per State');

# %% [markdown]
# #### SAT vs. ACT verbal/reading scores for 2017

# %%
# SAT vs. ACT verbal/reading scores  scores for 2017
plt.figure(figsize=(5,5))
plt.title('2017 SAT ERW vs ACT Reading Scores')
sns.scatterplot(final['erw_sat17'], final['reading_act17'])
plt.xlabel("SAT 2017 Evidence-Based Reading and Writing Scores per State")
plt.ylabel("ACT 2017 Reading Scores per State");

# %% [markdown]
# #### SAT vs. ACT total/composite scores for 2017

# %%
# SAT vs. ACT  total/composite scores scores for 2017
plt.figure(figsize=(5,5))
plt.title('Average 2017 SAT Total vs. ACT Composite Scores per States')
sns.scatterplot(final['total_sat17'], final['composite_act17'])
plt.xlabel('SAT 2017 Total State Score Averages')
plt.ylabel('ACT 2017 State COmposite Score Averages')
;
# Out:
# ''

# %% [markdown]
# #### Total scores for SAT 2017 vs. 2018

# %%
# SAT vs. ACT  total/composite scores scores for 2017
plt.figure(figsize=(5,5))
plt.title('Average 2017 SAT Total Scores Per State vs. 2018 SAT Total Scores per States')
sns.scatterplot(final['total_sat17'], final['total_sat18'])
plt.xlabel('SAT 2017 Total State Score Averages')
plt.ylabel('SAT 2018 State COmposite Score Averages')
;
# Out:
# ''

# %% [markdown]
# #### Composite scores for ACT 2017 vs. 2018

# %%
# ACT 2017 vs 2018 total/composite scores scores for 2017
plt.figure(figsize=(5,5))
plt.title('Average 2017 ACT Composite Scores Per State \n vs. 2018 ACT Composite Scores per States')
sns.scatterplot(final['total_sat17'], final['total_sat18'])
plt.xlabel('ACT 2017 Composite State Score Averages')
plt.ylabel('ACT 2018 State Composite Score Averages')
;
# Out:
# ''

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %% [markdown]
# ### SAT Boxplots

# %%
sns.boxplot(final['participation_sat17']);
plt.title('Boxplot of 2017 SAT Participation Averages Per State')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2017 State SAT Participations');

# %%
sns.boxplot(final['erw_sat17']);
plt.title('Boxplot of 2017 SAT Evidence-Based Reading and Writing Averages Per State')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2017 State SAT ERW');

# %%
sns.boxplot(final['math_sat17']);
plt.title('Boxplot of 2017 SAT Math Score Averages Per State')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2017 State SAT Math Scores');

# %%
sns.boxplot(final['total_sat17']);
plt.title('Boxplot of 2017 Total SAT ')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2017 State SAT Scores');

# %%
sns.boxplot(final['participation_sat18']);
plt.title('Boxplot of 2018 SAT Participation Averages Per State')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2018 State SAT Participations');

# %%
sns.boxplot(final['erw_sat18']);
plt.title('Boxplot of 2018 SAT Evidence-Based Reading and Writing Averages Per State')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2018 State SAT ERW');

# %%
sns.boxplot(final['math_sat18']);
plt.title('Boxplot of 2018 SAT Math Score Averages Per State')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2018 State SAT Math Scores');

# %%
sns.boxplot(final['total_sat18']);
plt.title('Boxplot of 2018 States Total Average SAT Score')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2018 State SAT Scores');

# %% [markdown]
# ### ACT Boxplots

# %%
sns.boxplot(final['participation_act17']);
plt.title('Boxplot of 2017 ACT Participation Averages Per State')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2017 State ACT Participations');

# %%
sns.boxplot(final['english_act17']);
plt.title('Boxplot of 2017 ACT English Score Averages Per State')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2017 State ACT English Scores');

# %%
sns.boxplot(final['math_act17']);
plt.title('Boxplot of 2017 ACT Math Score Averages Per State')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2017 State ACT Math Scores');

# %%
sns.boxplot(final['reading_act17']);
plt.title('Boxplot of 2017 ACT Reading Score Averages Per State')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2017 State ACT Reading Scores');

# %%
sns.boxplot(final['science_act17']);
plt.title('Boxplot of 2017 ACT Science Score Averages Per State')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2017 State ACT Science Scores');

# %%
sns.boxplot(final['composite_act17']);
plt.title('Boxplot of 2017 ACT Composite Score Averages Per State')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2017 State ACT Composite Scores');

# %%
sns.boxplot(final['participation_act18']);
plt.title('Boxplot of 2018 ACT Participation Averages Per State')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2018 State ACT Participations');

# %%
sns.boxplot(final['composite_act18']);
plt.title('Boxplot of 2018 ACT Composite Score Averages Per State')
plt.xlabel('Min, Max, Median, Quartiles and Range of 2018 State ACT Composite Scores');

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ../assets/2018\ ACT\ Participation\ vs\ Composite\ Score.png

# %%
final.to_csv('final.csv')

# %%
final.head()
# Out:
#         state  participation_sat17  erw_sat17  math_sat17  total_sat17  \
# 0     Alabama                 0.05        593         572         1165
# 1      Alaska                 0.38        547         533         1080
# 2     Arizona                 0.30        563         553         1116
# 3    Arkansas                 0.03        614         594         1208
# 4  California                 0.53        531         524         1055
#
#    participation_act17  english_act17  math_act17  reading_act17  \
# 0                 1.00           18.9        18.4           19.7
# 1                 0.65           18.7        19.8           20.4
# 2                 0.62           18.6        19.8           20.1
# 3                 1.00           18.9        19.0           19.7
# 4                 0.31           22.5        22.7           23.1
#
#    science_act17  composite_act17  participation_sat18  erw_sat18  math_sat18  \
# ...

# %%
final.shape
# Out:
# (51, 17)

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# https://public.tableau.com/profile/christopher.williams7164#!/vizhome/CWProject1/2018SATParticipationRate?publish=yes

# %% [markdown]
# ![](../assets/2017_SAT_Average_Participation_Rate.png)

# %% [markdown]
# ![](../assets/2017_ACT_Average_Participation.png)

# %% [markdown]
# ![](../assets/2017_SAT_Average_Total_Scores.png)

# %% [markdown]
# ![](../assets/2017_ACT_Average_Composite_Scores.png)

# %% [markdown]
# ![](../assets/2018_SAT_Average_Participation_Rate.png)

# %% [markdown]
# ![](../assets/2018_ACT_Average_Participation.png)

# %% [markdown]
# ![](../assets/2018_ACT_Average_Composite_Scores.png)

# %% [markdown]
# ![](../assets/2018_SAT_Average_Total_Scores.png)

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:

# %%
final.corr()
# Out:
#                      participation_sat17  erw_sat17  math_sat17  total_sat17  \
# participation_sat17             1.000000  -0.874326   -0.855091    -0.867540
# erw_sat17                      -0.874326   1.000000    0.987056     0.996661
# math_sat17                     -0.855091   0.987056    1.000000     0.996822
# total_sat17                    -0.867540   0.996661    0.996822     1.000000
# participation_act17            -0.841234   0.716153    0.682572     0.701477
# english_act17                   0.686889  -0.461345   -0.420673    -0.441947
# math_act17                      0.710697  -0.486126   -0.420456    -0.454116
# reading_act17                   0.705352  -0.488441   -0.442410    -0.466558
# science_act17                   0.653670  -0.422130   -0.365515    -0.394559
# composite_act17                 0.694748  -0.470382   -0.417817    -0.445020
# participation_sat18             0.886419  -0.828044   -0.803079    -0.818398
# ...

# %%
final.describe().T
# Out:
#                      count         mean        std     min       25%      50%  \
# participation_sat17   51.0     0.398039   0.352766    0.02     0.040     0.38
# erw_sat17             51.0   569.117647  45.666901  482.00   533.500   559.00
# math_sat17            51.0   556.882353  47.121395  468.00   523.500   548.00
# total_sat17           51.0  1126.098039  92.494812  950.00  1055.500  1107.00
# participation_act17   51.0     0.652549   0.321408    0.08     0.310     0.69
# english_act17         51.0    20.931373   2.353677   16.30    19.000    20.70
# math_act17            51.0    21.182353   1.981989   18.00    19.400    20.90
# reading_act17         51.0    22.013725   2.067271   18.10    20.450    21.80
# science_act17         51.0    21.450980   1.739353   18.20    19.950    21.30
# composite_act17       51.0    21.519608   2.020695   17.80    19.800    21.40
# participation_sat18   51.0     0.466471   0.379915    0.02     0.045     0.52
# ...

# %%
final.iloc[[43],[0,1,4,11,14,5,10,15,16]]
# Out:
#     state  participation_sat17  total_sat17  participation_sat18  total_sat18  \
# 43  Texas                 0.62         1020                 0.66         1032
#
#     participation_act17  composite_act17  participation_act18  composite_act18
# 43                 0.45             20.7                 0.45             20.7

# %%
# SAT Participation vs Total Score 2017
g = sns.lmplot(x='participation_sat17', y='total_sat17', data=final)
plt.xlabel('2017 States SAT Participation')
plt.ylabel('2017 States Average Total SAT Score')
plt.title('2017 SAT Participation vs Total Score', fontsize=20);

# %%
# SAT Participation vs Total Score 2018
g = sns.lmplot(x='participation_sat18', y='total_sat18', data=final)
plt.xlabel('2018 States SAT Participation')
plt.ylabel('2018 States Average Total SAT Score')
plt.title('2018 SAT Participation vs Total Score', fontsize=20);

# %%
# ACT Participation vs Total Score 2017

plt.scatter(final['participation_act17'], final['composite_act17'])

# %%
# ACT Participation vs Total Score 2017

plt.scatter(final['participation_act17'], final['composite_act18'])
plt.xlabel('2017 States ACT Participation')
plt.ylabel('2017 States Average Composite ACT Score')
plt.title('2017 ACT Participation vs Composite Score', fontsize=20);

# %%
g = sns.lmplot(x='participation_act18', y='composite_act18', data=final)
plt.xlabel('2018 States ACT Participation')
plt.ylabel('2018 States Average Composite ACT Score')
plt.title('2018 ACT Participation vs Composite Score', fontsize=18);

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
#
# No we did not. Looking at the histograms in the section above, the data is not normally distributed because of numerous potential reasons. A few of them may be that decisions on whether or not to take the exam or to care about taking it, are different depending on desired student and state education policy outcomes.

# %%
final.columns
# Out:
# Index(['state', 'participation_sat17', 'erw_sat17', 'math_sat17',
#        'total_sat17', 'participation_act17', 'english_act17', 'math_act17',
#        'reading_act17', 'science_act17', 'composite_act17',
#        'participation_sat18', 'erw_sat18', 'math_sat18', 'total_sat18',
#        'participation_act18', 'composite_act18'],
#       dtype='object')

# %%
# could redo histograms of each column's data, but not necessary as done before

final['participation_sat17'].plot(kind='hist')
plt.title('SAT 2017 Participation')
plt.xlabel('Number of States in Each Bracket');

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
#
# See the chart below which points to evidence that the relationship between ACT and SAT Participation rates in 2017 are inverse meaning as a state has higher participation in one exam, on average that state has lower participation on the other.
#
# In regard to granularity, aggregation, the relationships between populations size & rates, considering the actually populations these data there is only so much time and resources that states can demand out of their students. As the SAT and ACT are testing for similar purposes, to determine the readiness of high schools students, yet testing via different manners, states may require only one test or the other or students may decided on one test or the other based on the desired college admittance criteria.

# %%
sns.lmplot(x='participation_act17', y='participation_sat17', data=final)
plt.xlabel('2017 States ACT Participation')
plt.ylabel('2017 States SAT Participation')
plt.title('2017 ACT vs SAT Participation Rates', fontsize=18);

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:
#
# No it is not, as they have different purposes on how they access student's academic readiness. Potentially they could be fit to be compared, but currently they are not ready nor apples to apples comparison.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# I choose Colorado, Illinois and Texas as my 3 states of focus. Particularly paying attention to the implications for Texas as discussed in the intro.
#
# Colorado and Illinois changed there mandate from class of 2017 to 2018 to mandate the SAT. It is interesting to see the trend of as the size of participation increases, the averages scores decrease and how to use that info to make sure that the College Board is ready to present that to Texas education policy decision makers.

# %%
# 2017 to 2018 SAT Participation and Total Average Score for CO, IL, and Texas
df_outside = final.iloc[[5,13,43],[0,1,4,11,14]]
df_outside
# Out:
#        state  participation_sat17  total_sat17  participation_sat18  \
# 5   Colorado                 0.11         1201                 1.00
# 13  Illinois                 0.09         1115                 0.99
# 43     Texas                 0.62         1020                 0.66
#
#     total_sat18
# 5          1025
# 13         1019
# 43         1032

# %%
#  melting dataframe to create boxplots
df_outside_part = final.iloc[[5,13,43],[0,1,11]]

# %%
df_outside_total = final.iloc[[5,13,43],[0,4,14]]

# %%
# df_outside_part['state'] = df_outside_part.index

# %%
df_outside_part_melted = pd.melt(df_outside_part, 
                                 id_vars=['state'], 
                                 value_vars = ['participation_sat17','participation_sat18'] )

df_outside_part_melted
# Out:
#       state             variable  value
# 0  Colorado  participation_sat17   0.11
# 1  Illinois  participation_sat17   0.09
# 2     Texas  participation_sat17   0.62
# 3  Colorado  participation_sat18   1.00
# 4  Illinois  participation_sat18   0.99
# 5     Texas  participation_sat18   0.66

# %%
df_outside_part_melted
# Out:
#       state             variable  value
# 0  Colorado  participation_sat17   0.11
# 1  Illinois  participation_sat17   0.09
# 2     Texas  participation_sat17   0.62
# 3  Colorado  participation_sat18   1.00
# 4  Illinois  participation_sat18   0.99
# 5     Texas  participation_sat18   0.66

# %%
fig, ax = plt.subplots(figsize = (8,8))
sns.barplot(x='value',
           y='state',
           palette = {'participation_sat17': 'xkcd:cerulean', 'participation_sat18': 'xkcd:baby blue'},
              hue_order = ['participation_sat17', 'participation_sat18'],
           hue = 'variable',
           data = df_outside_part_melted).set_title('SAT Participation Score by State');

# %%
# 2017 SAT info on CO, IL, TX

final.iloc[[5,13,43],0:5]
# Out:
#        state  participation_sat17  erw_sat17  math_sat17  total_sat17
# 5   Colorado                 0.11        606         595         1201
# 13  Illinois                 0.09        559         556         1115
# 43     Texas                 0.62        513         507         1020

# %%
# 2017 and 2018 SAT info on CO, IL, TX
final.iloc[[5,13,43],[0,1,2,3,4,11,12,13,14]]
# Out:
#        state  participation_sat17  erw_sat17  math_sat17  total_sat17  \
# 5   Colorado                 0.11        606         595         1201
# 13  Illinois                 0.09        559         556         1115
# 43     Texas                 0.62        513         507         1020
#
#     participation_sat18  erw_sat18  math_sat18  total_sat18
# 5                  1.00        519         506         1025
# 13                 0.99        513         506         1019
# 43                 0.66        520         512         1032

# %%
# 2017 and 2018 SAT and ACT Participation Rates and Average Total / Composite Scores on CO, IL, TX
final.iloc[[5,13,43],[0,1,4,11,14,5,10,15,16]]
# Out:
#        state  participation_sat17  total_sat17  participation_sat18  \
# 5   Colorado                 0.11         1201                 1.00
# 13  Illinois                 0.09         1115                 0.99
# 43     Texas                 0.62         1020                 0.66
#
#     total_sat18  participation_act17  composite_act17  participation_act18  \
# 5          1025                 1.00             20.8                 0.30
# 13         1019                 0.93             21.4                 0.43
# 43         1032                 0.45             20.7                 0.45
#
#     composite_act18
# 5              23.9
# 13             23.9
# 43             20.7

# %%
final.iloc[[43],[0,1,4,11,14,5,10,15,16]]
# Out:
#     state  participation_sat17  total_sat17  participation_sat18  total_sat18  \
# 43  Texas                 0.62         1020                 0.66         1032
#
#     participation_act17  composite_act17  participation_act18  composite_act18
# 43                 0.45             20.7                 0.45             20.7

# %% [markdown]
# Sources and Links
#
# - 2018 state-by-state average results and participation for the SAT are available in PDF reports [here](https://reports.collegeboard.org/sat-suite-program-results/state-results).
# - 2018 ACT state-by-state mean composite scores and  participation rates are [here](http://www.act.org/content/dam/act/unsecured/documents/cccr2018/Average-Scores-by-State.pdf) .
# - SAT Results - Class of 2018 (https://reports.collegeboard.org/sat-suite-program-results/class-2018-results)
# - CollegeBoard 2018 SAT Suite of Assessments Annual Report Texas (https://reports.collegeboard.org/pdf/2018-texas-sat-suite-assessments-annual-report.pdf)
# - Here are the Average SAT Scores by State (https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - How the New SAT Is Scored (https://blog.collegevine.com/how-the-new-sat-is-scored/)
# - How Is the ACT Scored? (https://blog.prepscholar.com/how-is-the-act-scored)
# - All Average ACT Scores by State (2017) (https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)
# - SAT Texas (https://reports.collegeboard.org/pdf/2017-texas-sat-suite-assessments-annual-report.pdf)
# - SAT California (https://reports.collegeboard.org/pdf/2018-california-sat-suite-assessments-annual-report.pdf)
# - Which States Require Students to Take the SAT or ACT? (An Interactive Breakdown of States’ 2016-17 Testing Plans)(https://www.edweek.org/ew/section/multimedia/states-require-students-take-sat-or-act.html)
# - Texas wants schools to pay for ACT and SAT exams. Local districts say that’s unreasonable. (https://www.texastribune.org/2018/10/03/standardized-testing-ACT-SAT-pay-Texas/)
# - 18_08 Proposed Amendment to 19 TAC §101.3011 (https://tea.texas.gov/About_TEA/Laws_and_Rules/Commissioner_Rules_(TAC)/Proposed/18_08_Proposed_Amendment_to_19_TAC_%C2%A7101_3011/)

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# #### Conclusions
#
# The College Board needs to continue to prove the merit of the SAT as a measure of college preparation for High School Students.
#
# The College Board must overcome policy makers potential to misunderstand the findings that as state SAT exam participation increases average SAT scores fall.
#
#
#
# #### Recommendations
#
# Utilize data demonstrating that the SAT is a better assessment of High Schools student’s core math and  reading assessments than the Texas STARR exams.
#
# Find and analyze data on how successful students are during college that use the SAT versus ACT as the entrance exam and thus the barometer for their college preparation.
